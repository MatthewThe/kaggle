# %%
import pandas as pd
import numpy as np
import re
import itertools

# %% [markdown]
# ###1. Load train and test data

# %%
train = pd.read_csv("data/train.csv")
train["dataset"] = "train"
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked dataset
# 0      0         A/5 21171   7.2500   NaN        S   train
# 1      0          PC 17599  71.2833   C85        C   train
# 2      0  STON/O2. 3101282   7.9250   NaN        S   train
# 3      0            113803  53.1000  C123        S   train
# 4      0            373450   8.0500   NaN        S   train

# %%
test = pd.read_csv("data/test.csv")
test["dataset"] = "test"
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked dataset
# 0  34.5      0      0   330911   7.8292   NaN        Q    test
# 1  47.0      1      0   363272   7.0000   NaN        S    test
# 2  62.0      0      0   240276   9.6875   NaN        Q    test
# 3  27.0      0      0   315154   8.6625   NaN        S    test
# 4  22.0      1      1  3101298  12.2875   NaN        S    test

# %%
#Combine both datasets to predict families
train = train.append(test)
train.set_index(train["PassengerId"],inplace=True)

# %% [markdown]
# ##2. Tokenize name into (surname, title, first name and maiden name)

# %%
name_tokenizer = re.compile(r"^(?P<surname>[^,]+), (?P<title>[A-Z a-z]+?)\. (?P<f_name>[A-Z a-z.]+)?(?P<maiden_name>\([A-Za-z .]+\))?")

# %%
name_tokens = ["surname","title","f_name","maiden_name"]
for name_tk in name_tokens:
    train[name_tk] = train.Name.apply(lambda x: name_tokenizer.match(x).group(name_tk))
    test[name_tk] = test.Name.apply(lambda x: name_tokenizer.match(x).group(name_tk))
train.head(n=5)
# Out:
#              Age Cabin Embarked     Fare  \
# PassengerId
# 1             22   NaN        S   7.2500
# 2             38   C85        C  71.2833
# 3             26   NaN        S   7.9250
# 4             35  C123        S  53.1000
# 5             35   NaN        S   8.0500
#
#                                                           Name  Parch  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris      0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      0
# 3                                       Heikkinen, Miss. Laina      0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      0
# 5                                     Allen, Mr. William Henry      0
#
#              PassengerId  Pclass     Sex  SibSp  Survived            Ticket  \
# PassengerId
# 1                      1       3    male      1         0         A/5 21171
# 2                      2       1  female      1         1          PC 17599
# 3                      3       3  female      0         1  STON/O2. 3101282
# 4                      4       1  female      1         1            113803
# 5                      5       3    male      0         0            373450
#
#             dataset    surname title          f_name               maiden_name
# PassengerId
# 1             train     Braund    Mr     Owen Harris                      None
# 2             train    Cumings   Mrs   John Bradley   (Florence Briggs Thayer)
# 3             train  Heikkinen  Miss           Laina                      None
# 4             train   Futrelle   Mrs  Jacques Heath            (Lily May Peel)
# 5             train      Allen    Mr   William Henry                      None

# %% [markdown]
# ###2.1 Extract features from Title variable

# %%
print train.groupby(["title","Sex"]).size()
# Out:
# title         Sex
# Capt          male        1
# Col           male        4
# Don           male        1
# Dona          female      1
# Dr            female      1
#               male        7
# Jonkheer      male        1
# Lady          female      1
# Major         male        2
# Master        male       61
# Miss          female    260
# Mlle          female      2
# Mme           female      1
# Mr            male      757
# Mrs           female    197
# Ms            female      2
# Rev           male        8
# Sir           male        1
# the Countess  female      1
# dtype: int64

# %% [markdown]
# It seems we can extract some info from title
# 1. Whether a woman is married Mme/Mrs vs Miss/Mlle  vs Ms(Undetermined or single :/? )
# 2. Master title apparently given to male kids
# 2. Nobility vs laypeople : (Dr, Col, Capt,  ...) vs (Mr,Master,Mrs,Miss). Ambiguous cases (Mlle,Mme,Ms,Don/Dona?)

# %%
#Encode special title following this logic
train.has_special_title = train.title.apply(lambda x: x not in ["Mr","Mrs","Miss","Mme","Mlle","Master"])

# %% [markdown]
# ##3 Examine marriages / sibling relationships

# %%
def is_married(couple_rows):
    are_married=False
    if couple_rows.irow(0).Sex != couple_rows.irow(1).Sex:
        #Get who is the husband and whose the wife
        man = couple_rows.irow(0) if couple_rows.irow(0).Sex == "male" else couple_rows.irow(1)
        woman = couple_rows.irow(0) if couple_rows.irow(0).Sex == "female" else couple_rows.irow(1)

        #Marriage tests
        marriage_tests = {}
        marriage_tests["same_f_name"] = woman.f_name is not None and woman.f_name in man.f_name
        marriage_tests["consistent_title"] =  woman.title not in ("Miss","Mlle") and man.title != "Master"
        marriage_tests["same_ticket"] = woman.Ticket == man.Ticket
        marriage_tests["same_pclass"] = woman.Pclass == man.Pclass
        marriage_tests["legal_age"] = (woman.title in ("Mme","Mrs") or woman.Age >= 10) and man.Age > 10
        marriage_tests["consistent_SibSp"] = (woman.SibSp > 0 and man.SibSp > 0) or (woman.SibSp == man.SibSp)

        are_married = marriage_tests["same_f_name"] and marriage_tests["legal_age"] or ( )
        
        consistency_checks = ( marriage_tests["consistent_title"] and 
                               marriage_tests["legal_age"] and 
                              marriage_tests["same_pclass"] and 
                              marriage_tests["same_ticket"] and
                              marriage_tests["consistent_SibSp"])

        if are_married and not consistency_checks:
            failed_tests = ", ".join("{}:{}".format(x,marriage_tests[x]) for x in marriage_tests if not marriage_tests[x])
            print "WARNING: Sketchy marriage: {}".format(failed_tests)
            print couple_rows
            
            print

    return are_married

# %% [markdown]
# ##Initialize data structures for algorithm

# %%
#Data structures - sets to keep track which ones have already been assigned
married_people = set()
people_with_parents = set()

# %%
links_to_assign = train[["SibSp","Parch"]]
#Matches a couple with the Max amount of kids they can have 
#Which is the min(husband.Parch, wife.Parch)
marriages_table = {}

# %% [markdown]
# ### 1. Extract marriages in greedy fashion. Assume is_married has no fp ( might have actually :/ )

# %%
#Subset only people who have spouses/siblings on the boat
train_sibsp = train.ix[ train.SibSp > 0]
#People grouped by surname
surname_groups = train_sibsp.groupby("surname").groups

# %%
for surname in surname_groups:
    surname_rows = surname_groups[surname]
    couples = itertools.combinations(surname_rows,2)
    for cpl in couples:
        cpl_rows = train_sibsp.ix[list(cpl)]
        if is_married(cpl_rows):
            #Make sure we're not marrying somebody twice :p
            assert cpl[0] not in married_people,"{} is already married :/".format(cpl[0])
            assert cpl[1] not in married_people,"{} is already married :/".format(cpl[1])
            
            #add couples to married set
            married_people.add(cpl[0])
            married_people.add(cpl[1])
            
            marriages_table[cpl] = min(links_to_assign.ix[cpl[0]]["Parch"], links_to_assign.ix[cpl[1]]["Parch"] )
            
            
            #print
#    break

# %%
marriages_table
# Out:
# {(26, 1066): 5, (94, 924): 2, (152, 337): 0, (609, 686): 2, (737, 1059): 2}

# %%
train.ix[list((26,1066))]

# %%
train.ix[ (train.SibSp > 0) | (train.Parch > 0) ].shape
# Out:
# (519, 17)

# %%
train
# Out:
#               Age        Cabin Embarked      Fare  \
# PassengerId
# 1            22.0          NaN        S    7.2500
# 2            38.0          C85        C   71.2833
# 3            26.0          NaN        S    7.9250
# 4            35.0         C123        S   53.1000
# 5            35.0          NaN        S    8.0500
# 6             NaN          NaN        Q    8.4583
# 7            54.0          E46        S   51.8625
# 8             2.0          NaN        S   21.0750
# 9            27.0          NaN        S   11.1333
# 10           14.0          NaN        C   30.0708
# 11            4.0           G6        S   16.7000
# 12           58.0         C103        S   26.5500
# 13           20.0          NaN        S    8.0500
# 14           39.0          NaN        S   31.2750
# 15           14.0          NaN        S    7.8542
# 16           55.0          NaN        S   16.0000
# 17            2.0          NaN        Q   29.1250
# 18            NaN          NaN        S   13.0000
# 19           31.0          NaN        S   18.0000
# 20            NaN          NaN        C    7.2250
# 21           35.0          NaN        S   26.0000
# 22           34.0          D56        S   13.0000
# 23           15.0          NaN        Q    8.0292
# 24           28.0           A6        S   35.5000
# 25            8.0          NaN        S   21.0750
# 26           38.0          NaN        S   31.3875
# 27            NaN          NaN        C    7.2250
# 28           19.0  C23 C25 C27        S  263.0000
# 29            NaN          NaN        Q    7.8792
# 30            NaN          NaN        S    7.8958
# ...           ...          ...      ...       ...
# 1280         21.0          NaN        Q    7.7500
# 1281          6.0          NaN        S   21.0750
# 1282         23.0          B24        S   93.5000
# 1283         51.0          D28        S   39.4000
# 1284         13.0          NaN        S   20.2500
# 1285         47.0          NaN        S   10.5000
# 1286         29.0          NaN        S   22.0250
# 1287         18.0          C31        S   60.0000
# 1288         24.0          NaN        Q    7.2500
# 1289         48.0          B41        C   79.2000
# 1290         22.0          NaN        S    7.7750
# 1291         31.0          NaN        Q    7.7333
# 1292         30.0           C7        S  164.8667
# 1293         38.0          NaN        S   21.0000
# 1294         22.0          NaN        C   59.4000
# 1295         17.0          NaN        S   47.1000
# 1296         43.0          D40        C   27.7208
# 1297         20.0          D38        C   13.8625
# 1298         23.0          NaN        S   10.5000
# 1299         50.0          C80        C  211.5000
# 1300          NaN          NaN        Q    7.7208
# 1301          3.0          NaN        S   13.7750
# 1302          NaN          NaN        Q    7.7500
# 1303         37.0          C78        Q   90.0000
# 1304         28.0          NaN        S    7.7750
# 1305          NaN          NaN        S    8.0500
# 1306         39.0         C105        C  108.9000
# 1307         38.5          NaN        S    7.2500
# 1308          NaN          NaN        S    8.0500
# 1309          NaN          NaN        C   22.3583
#
#                                                           Name  Parch  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris      0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      0
# 3                                       Heikkinen, Miss. Laina      0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      0
# 5                                     Allen, Mr. William Henry      0
# 6                                             Moran, Mr. James      0
# 7                                      McCarthy, Mr. Timothy J      0
# 8                               Palsson, Master. Gosta Leonard      1
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      2
# 10                         Nasser, Mrs. Nicholas (Adele Achem)      0
# 11                             Sandstrom, Miss. Marguerite Rut      1
# 12                                    Bonnell, Miss. Elizabeth      0
# 13                              Saundercock, Mr. William Henry      0
# 14                                 Andersson, Mr. Anders Johan      5
# 15                        Vestrom, Miss. Hulda Amanda Adolfina      0
# 16                            Hewlett, Mrs. (Mary D Kingcome)       0
# 17                                        Rice, Master. Eugene      1
# 18                                Williams, Mr. Charles Eugene      0
# 19           Vander Planke, Mrs. Julius (Emelia Maria Vande...      0
# 20                                     Masselmani, Mrs. Fatima      0
# 21                                        Fynney, Mr. Joseph J      0
# 22                                       Beesley, Mr. Lawrence      0
# 23                                 McGowan, Miss. Anna "Annie"      0
# 24                                Sloper, Mr. William Thompson      0
# 25                               Palsson, Miss. Torborg Danira      1
# 26           Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...      5
# 27                                     Emir, Mr. Farred Chehab      0
# 28                              Fortune, Mr. Charles Alexander      2
# 29                               O'Dwyer, Miss. Ellen "Nellie"      0
# 30                                         Todoroff, Mr. Lalio      0
# ...                                                        ...    ...
# 1280                                      Canavan, Mr. Patrick      0
# 1281                               Palsson, Master. Paul Folke      1
# 1282                                Payne, Mr. Vivian Ponsonby      0
# 1283            Lines, Mrs. Ernest H (Elizabeth Lindsey James)      1
# 1284                             Abbott, Master. Eugene Joseph      2
# 1285                                      Gilbert, Mr. William      0
# 1286                                  Kink-Heilmann, Mr. Anton      1
# 1287            Smith, Mrs. Lucien Philip (Mary Eloise Hughes)      0
# 1288                                      Colbert, Mr. Patrick      0
# 1289         Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...      1
# 1290                            Larsson-Rondberg, Mr. Edvard A      0
# 1291                                  Conlon, Mr. Thomas Henry      0
# 1292                                   Bonnell, Miss. Caroline      0
# 1293                                           Gale, Mr. Harry      0
# 1294                            Gibson, Miss. Dorothy Winifred      1
# 1295                                    Carrau, Mr. Jose Pedro      0
# 1296                              Frauenthal, Mr. Isaac Gerald      0
# 1297              Nourney, Mr. Alfred (Baron von Drachstedt")"      0
# 1298                                 Ware, Mr. William Jeffery      0
# 1299                                Widener, Mr. George Dunton      1
# 1300                           Riordan, Miss. Johanna Hannah""      0
# 1301                                 Peacock, Miss. Treasteall      1
# 1302                                    Naughton, Miss. Hannah      0
# 1303           Minahan, Mrs. William Edward (Lillian E Thorpe)      0
# 1304                            Henriksson, Miss. Jenny Lovisa      0
# 1305                                        Spector, Mr. Woolf      0
# 1306                              Oliva y Ocana, Dona. Fermina      0
# 1307                              Saether, Mr. Simon Sivertsen      0
# 1308                                       Ware, Mr. Frederick      0
# 1309                                  Peter, Master. Michael J      1
#
#              PassengerId  Pclass     Sex  SibSp  Survived              Ticket  \
# PassengerId
# 1                      1       3    male      1         0           A/5 21171
# 2                      2       1  female      1         1            PC 17599
# 3                      3       3  female      0         1    STON/O2. 3101282
# 4                      4       1  female      1         1              113803
# 5                      5       3    male      0         0              373450
# 6                      6       3    male      0         0              330877
# 7                      7       1    male      0         0               17463
# 8                      8       3    male      3         0              349909
# 9                      9       3  female      0         1              347742
# 10                    10       2  female      1         1              237736
# 11                    11       3  female      1         1             PP 9549
# 12                    12       1  female      0         1              113783
# 13                    13       3    male      0         0           A/5. 2151
# 14                    14       3    male      1         0              347082
# 15                    15       3  female      0         0              350406
# 16                    16       2  female      0         1              248706
# 17                    17       3    male      4         0              382652
# 18                    18       2    male      0         1              244373
# 19                    19       3  female      1         0              345763
# 20                    20       3  female      0         1                2649
# 21                    21       2    male      0         0              239865
# 22                    22       2    male      0         1              248698
# 23                    23       3  female      0         1              330923
# 24                    24       1    male      0         1              113788
# 25                    25       3  female      3         0              349909
# 26                    26       3  female      1         1              347077
# 27                    27       3    male      0         0                2631
# 28                    28       1    male      3         0               19950
# 29                    29       3  female      0         1              330959
# 30                    30       3    male      0         0              349216
# ...                  ...     ...     ...    ...       ...                 ...
# 1280                1280       3    male      0       NaN              364858
# 1281                1281       3    male      3       NaN              349909
# 1282                1282       1    male      0       NaN               12749
# 1283                1283       1  female      0       NaN            PC 17592
# 1284                1284       3    male      0       NaN           C.A. 2673
# 1285                1285       2    male      0       NaN          C.A. 30769
# 1286                1286       3    male      3       NaN              315153
# 1287                1287       1  female      1       NaN               13695
# 1288                1288       3    male      0       NaN              371109
# 1289                1289       1  female      1       NaN               13567
# 1290                1290       3    male      0       NaN              347065
# 1291                1291       3    male      0       NaN               21332
# 1292                1292       1  female      0       NaN               36928
# 1293                1293       2    male      1       NaN               28664
# 1294                1294       1  female      0       NaN              112378
# 1295                1295       1    male      0       NaN              113059
# 1296                1296       1    male      1       NaN               17765
# 1297                1297       2    male      0       NaN       SC/PARIS 2166
# 1298                1298       2    male      1       NaN               28666
# 1299                1299       1    male      1       NaN              113503
# 1300                1300       3  female      0       NaN              334915
# 1301                1301       3  female      1       NaN  SOTON/O.Q. 3101315
# 1302                1302       3  female      0       NaN              365237
# 1303                1303       1  female      1       NaN               19928
# 1304                1304       3  female      0       NaN              347086
# 1305                1305       3    male      0       NaN           A.5. 3236
# 1306                1306       1  female      0       NaN            PC 17758
# 1307                1307       3    male      0       NaN  SOTON/O.Q. 3101262
# 1308                1308       3    male      0       NaN              359309
# 1309                1309       3    male      1       NaN                2668
#
#             dataset           surname   title                 f_name  \
# PassengerId
# 1             train            Braund      Mr            Owen Harris
# 2             train           Cumings     Mrs          John Bradley
# 3             train         Heikkinen    Miss                  Laina
# 4             train          Futrelle     Mrs         Jacques Heath
# 5             train             Allen      Mr          William Henry
# 6             train             Moran      Mr                  James
# 7             train          McCarthy      Mr              Timothy J
# 8             train           Palsson  Master          Gosta Leonard
# 9             train           Johnson     Mrs               Oscar W
# 10            train            Nasser     Mrs              Nicholas
# 11            train         Sandstrom    Miss         Marguerite Rut
# 12            train           Bonnell    Miss              Elizabeth
# 13            train       Saundercock      Mr          William Henry
# 14            train         Andersson      Mr           Anders Johan
# 15            train           Vestrom    Miss  Hulda Amanda Adolfina
# 16            train           Hewlett     Mrs                   None
# 17            train              Rice  Master                 Eugene
# 18            train          Williams      Mr         Charles Eugene
# 19            train     Vander Planke     Mrs                Julius
# 20            train        Masselmani     Mrs                 Fatima
# 21            train            Fynney      Mr               Joseph J
# 22            train           Beesley      Mr               Lawrence
# 23            train           McGowan    Miss                  Anna
# 24            train            Sloper      Mr       William Thompson
# 25            train           Palsson    Miss         Torborg Danira
# 26            train           Asplund     Mrs            Carl Oscar
# 27            train              Emir      Mr          Farred Chehab
# 28            train           Fortune      Mr      Charles Alexander
# 29            train           O'Dwyer    Miss                 Ellen
# 30            train          Todoroff      Mr                  Lalio
# ...             ...               ...     ...                    ...
# 1280           test           Canavan      Mr                Patrick
# 1281           test           Palsson  Master             Paul Folke
# 1282           test             Payne      Mr        Vivian Ponsonby
# 1283           test             Lines     Mrs              Ernest H
# 1284           test            Abbott  Master          Eugene Joseph
# 1285           test           Gilbert      Mr                William
# 1286           test     Kink-Heilmann      Mr                  Anton
# 1287           test             Smith     Mrs         Lucien Philip
# 1288           test           Colbert      Mr                Patrick
# 1289           test  Frolicher-Stehli     Mrs            Maxmillian
# 1290           test  Larsson-Rondberg      Mr               Edvard A
# 1291           test            Conlon      Mr           Thomas Henry
# 1292           test           Bonnell    Miss               Caroline
# 1293           test              Gale      Mr                  Harry
# 1294           test            Gibson    Miss       Dorothy Winifred
# 1295           test            Carrau      Mr             Jose Pedro
# 1296           test        Frauenthal      Mr           Isaac Gerald
# 1297           test           Nourney      Mr                Alfred
# 1298           test              Ware      Mr        William Jeffery
# 1299           test           Widener      Mr          George Dunton
# 1300           test           Riordan    Miss         Johanna Hannah
# 1301           test           Peacock    Miss             Treasteall
# 1302           test          Naughton    Miss                 Hannah
# 1303           test           Minahan     Mrs        William Edward
# 1304           test        Henriksson    Miss           Jenny Lovisa
# 1305           test           Spector      Mr                  Woolf
# 1306           test     Oliva y Ocana    Dona                Fermina
# 1307           test           Saether      Mr        Simon Sivertsen
# 1308           test              Ware      Mr              Frederick
# 1309           test             Peter  Master              Michael J
#
#                                   maiden_name
# PassengerId
# 1                                        None
# 2                    (Florence Briggs Thayer)
# 3                                        None
# 4                             (Lily May Peel)
# 5                                        None
# 6                                        None
# 7                                        None
# 8                                        None
# 9                 (Elisabeth Vilhelmina Berg)
# 10                              (Adele Achem)
# 11                                       None
# 12                                       None
# 13                                       None
# 14                                       None
# 15                                       None
# 16                          (Mary D Kingcome)
# 17                                       None
# 18                                       None
# 19               (Emelia Maria Vandemoortele)
# 20                                       None
# 21                                       None
# 22                                       None
# 23                                       None
# 24                                       None
# 25                                       None
# 26           (Selma Augusta Emilia Johansson)
# 27                                       None
# 28                                       None
# 29                                       None
# 30                                       None
# ...                                       ...
# 1280                                     None
# 1281                                     None
# 1282                                     None
# 1283                (Elizabeth Lindsey James)
# 1284                                     None
# 1285                                     None
# 1286                                     None
# 1287                     (Mary Eloise Hughes)
# 1288                                     None
# 1289            (Margaretha Emerentia Stehli)
# 1290                                     None
# 1291                                     None
# 1292                                     None
# 1293                                     None
# 1294                                     None
# 1295                                     None
# 1296                                     None
# 1297                                     None
# 1298                                     None
# 1299                                     None
# 1300                                     None
# 1301                                     None
# 1302                                     None
# 1303                       (Lillian E Thorpe)
# 1304                                     None
# 1305                                     None
# 1306                                     None
# 1307                                     None
# 1308                                     None
# 1309                                     None
#
# [1309 rows x 17 columns]
